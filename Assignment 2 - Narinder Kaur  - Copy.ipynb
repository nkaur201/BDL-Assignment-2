# %% [markdown]
# # Big Data Landscapes - Assignent 2
#
# Name: Narinder Kaur
# Student ID: S1516125
# Assignment Title: "Why employees may leave jobs in NYC"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data Upload

# %% [markdown]
# # New Cars Dataset:

# %%
url = 'https://raw.githubusercontent.com/nkaur201/BDL-Assignment-2/master/NewCars.csv'

#create a dictonary
NewCars= pd.read_csv(url, keep_default_na=False, na_values=["NaN"])


(NewCars.head(10))
NewCars.shape
# Out:
# (9355, 12)

# %%
NewCars.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
#        'Transmission Type', 'Driven Mode', 'Number of Doors', 'highway MPG',
#        'city mpg', 'Popularity', 'Price'],
#       dtype='object')

# %%
NewCars['Brand'].unique().shape
# Out:
# (33,)

# %%
NewCars.shape
# Out:
# (9355, 12)

# %%
NewCars.describe()
# Out:
#        Brand Model  Year Engine HP Engine Cylinders Transmission Type  \
# count   9355  9355  9355      9355             9355              9355
# unique    33   618    29       304               10                 6
# top                                               6         AUTOMATIC
# freq    1767  1767  1767      1804             3151              5467
#
#               Driven Mode Number of Doors highway MPG city mpg Popularity  \
# count                9355            9355        9355     9355       9355
# unique                  5               4          47       49         33
# top     front wheel drive               4
# freq                 2621            5208        1767     1767       1767
#
#        Price
# count   9355
# unique  4565
# top
# freq    1767

# %% [markdown]
# # Car Sales Dataset:

# %%
url = 'https://raw.githubusercontent.com/nkaur201/BDL-Assignment-2/master/CarSales.csv'
CarSales= pd.read_csv(url, keep_default_na=False, encoding='latin-1', na_values=[""])


(CarSales.head(15))
# Out:
#          Brand    price       body  mileage engV engType registration  year  \
# 0        Acura  15000.0      sedan      150  3.5     Gas          yes  2008
# 1        Acura  15650.0  crossover      170  3.7  Petrol          yes  2008
# 2        Acura   8699.0      sedan      144  3.2     Gas          yes  2005
# 3        Acura  11111.0  crossover      199  3.5  Petrol          yes  2005
# 4        Acura  12900.0      sedan      126  3.5     Gas          yes  2006
# 5        Acura  46999.0  crossover       30  3.5  Petrol          yes  2014
# 6        Acura  17200.0  crossover       82  3.7  Petrol          yes  2008
# 7        Acura   8550.0      sedan      145  3.2  Petrol          yes  2005
# 8        Acura   8699.0      sedan      145  3.2     Gas          yes  2005
# 9        Acura  30999.0  crossover       32  3.7   Other          yes  2010
# 10       Acura   8700.0      sedan      145  3.2     Gas          yes  2005
# ...

# %%
CarSales.columns
# Out:
# Index(['Brand', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
CarSales['Brand'].unique().shape
# Out:
# (87,)

# %%
CarSales.shape
# Out:
# (9576, 10)

# %%
CarSales.describe()
# Out:
#                price      mileage         year
# count    9576.000000  9576.000000  9576.000000
# mean    15633.317316   138.862364  2006.605994
# std     24106.523436    98.629754     7.067924
# min         0.000000     0.000000  1953.000000
# 25%      4999.000000    70.000000  2004.000000
# 50%      9200.000000   128.000000  2008.000000
# 75%     16700.000000   194.000000  2012.000000
# max    547800.000000   999.000000  2016.000000

# %%
CarSales.count()
# Out:
# Brand           9576
# price           9576
# body            9576
# mileage         9576
# engV            9576
# engType         9576
# registration    9576
# year            9576
# model           9576
# drive           9065
# dtype: int64

# %% [markdown]
# # BMW Dataset

# %%
url = 'https://raw.githubusercontent.com/nkaur201/BDL-Assignment-2/master/BMW.csv'
BMW = pd.read_csv(url, keep_default_na=False, encoding='latin-1', na_values=[""])

(BMW.head(15))
# Out:
#    Brand model_key  mileage  engine_power    fuel paint_color     car_type  \
# 0    BMW       118   140411           100  diesel       black  convertible
# 1    BMW        M4    13929           317  petrol        grey  convertible
# 2    BMW       320   183297           120  diesel       white  convertible
# 3    BMW       420   128035           135  diesel         red  convertible
# 4    BMW       425    97097           160  diesel      silver  convertible
# 5    BMW       335   152352           225  petrol       black  convertible
# 6    BMW       325   205219           145  diesel        grey  convertible
# 7    BMW       118   115560           105  petrol       white  convertible
# 8    BMW        Z4   123886           125  petrol       black  convertible
# 9    BMW       320   139541           135  diesel       white  convertible
# 10   BMW       320    77115           135  diesel        blue  convertible
# ...

# %%
BMW.columns
# Out:
# Index(['Brand', 'model_key', 'mileage', 'engine_power', 'fuel', 'paint_color',
#        'car_type', 'price'],
#       dtype='object')

# %%
BMW['Brand'].unique().shape
# Out:
# (1,)

# %%
BMW.shape
# Out:
# (4843, 8)

# %%
BMW.count()
# Out:
# Brand           4843
# model_key       4843
# mileage         4843
# engine_power    4843
# fuel            4843
# paint_color     4843
# car_type        4843
# price           4843
# dtype: int64

# %%
#print("There are {} rows and {} columns in our data".format(job_postings.shape[0], job_postings.shape[1]))

# %% [markdown]
# Data Integration

# %%
#MergedDataFrame1 = pd.merge(NewCars,CarSales,on = 'Brand')
#MergedDataFrame1.head(10)
NewCars2 = NewCars.reindex(index = NewCars['Brand'])
#mdtest = pd.DataFrame.join()
NewCars = NewCars[~NewCars['Brand'].isnull()] #rows which are not empty #data cleaning check for indexex and null values - irrelevent 
NewCars

#pd.DataFrame.join
# Out:
#       Brand Model  Year Engine HP Engine Cylinders Transmission Type  \
# 0     Acura    CL  2001       225                6         AUTOMATIC
# 1     Acura    CL  2001       225                6         AUTOMATIC
# 2     Acura    CL  2002       225                6         AUTOMATIC
# 3     Acura    CL  2002       225                6         AUTOMATIC
# 4     Acura    CL  2003       260                6            MANUAL
# ...     ...   ...   ...       ...              ...               ...
# 9350
# 9351
# 9352
# 9353
# 9354
#
#             Driven Mode Number of Doors highway MPG city mpg Popularity  Price
# 0     front wheel drive               2          27       17        204  29980
# 1     front wheel drive               2          27       17        204  27980
# 2     front wheel drive               2          27       17        204  28030
# 3     front wheel drive               2          27       17        204  30030
# ...

# %%
MergedDataFrame1.shape
# Out:
# (1422063, 21)

# %%
MergedDataFrame1.isnull().sum()
# Out:
# Brand                    0
# Model                    0
# Year                     0
# Engine HP             7561
# Engine Cylinders      4452
# Transmission Type        0
# Driven Mode              0
# Number of Doors          2
# highway MPG              0
# city mpg                 0
# Popularity               0
# Price                    0
# price                    0
# body                     0
# mileage                  0
# engV                     0
# engType                  0
# registration             0
# year                     0
# model                    0
# drive                68705
# dtype: int64

# %%
NewMergedDataFrame1 = MergedDataFrame1.drop(['Engine HP','Engine Cylinders', 'Number of Doors', 'drive'], axis = 1)
NewMergedDataFrame1.head()
# Out:
#    Brand Model    Year Transmission Type        Driven Mode  highway MPG  \
# 0  Acura    CL  2001.0         AUTOMATIC  front wheel drive         27.0
# 1  Acura    CL  2001.0         AUTOMATIC  front wheel drive         27.0
# 2  Acura    CL  2001.0         AUTOMATIC  front wheel drive         27.0
# 3  Acura    CL  2001.0         AUTOMATIC  front wheel drive         27.0
# 4  Acura    CL  2001.0         AUTOMATIC  front wheel drive         27.0
#
#    city mpg  Popularity    Price    price       body  mileage engV engType  \
# 0      17.0       204.0  29980.0  15000.0      sedan      150  3.5     Gas
# 1      17.0       204.0  29980.0  15650.0  crossover      170  3.7  Petrol
# 2      17.0       204.0  29980.0   8699.0      sedan      144  3.2     Gas
# 3      17.0       204.0  29980.0  11111.0  crossover      199  3.5  Petrol
# 4      17.0       204.0  29980.0  12900.0      sedan      126  3.5     Gas
#
#   registration  year model
# 0          yes  2008    RL
# ...

# %%
NewMergedDataFrame1.isnull().sum()
# Out:
# Brand                0
# Model                0
# Year                 0
# Transmission Type    0
# Driven Mode          0
# highway MPG          0
# city mpg             0
# Popularity           0
# Price                0
# price                0
# body                 0
# mileage              0
# engV                 0
# engType              0
# registration         0
# year                 0
# model                0
# dtype: int64

# %%
MergedDataFrame2 = pd.merge(MergedDataFrame1,BMW,on = 'Brand')
MergedDataFrame2.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-95-d58d6e584953> in <module>
# ----> 1 MergedDataFrame2 = pd.merge(MergedDataFrame1,BMW,on = 'Brand')
#       2 MergedDataFrame2.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     640             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     641
# --> 642         join_index, left_indexer, right_indexer = self._get_join_info()
#     643
#     644         ldata, rdata = self.left._data, self.right._data
#
# ...
